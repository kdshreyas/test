# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2020-financial-year-provisional/Download-data/annual-enterprise-survey-2020-financial-year-provisional-csv.csv")

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df['Industry_aggregation_NZSIOC']
# Out:
# 0        Level 1
# 1        Level 1
# 2        Level 1
# 3        Level 1
# 4        Level 1
#           ...
# 37075    Level 3
# 37076    Level 3
# 37077    Level 3
# 37078    Level 3
# 37079    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 37080, dtype: object

# %%
df.sort_values('Industry_code_NZSIOC', ascending = False).head()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37079  2013                     Level 3                 ZZ11
# 9240   2019                     Level 3                 ZZ11
# 4616   2020                     Level 3                 ZZ11
# 4615   2020                     Level 3                 ZZ11
# 4614   2020                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 37079  Food product manufacturing          Percentage           H41
# 9240   Food Product Manufacturing  Dollars (millions)           H08
# 4616   Food Product Manufacturing  Dollars (millions)           H23
# 4615   Food Product Manufacturing  Dollars (millions)           H22
# 4614   Food Product Manufacturing  Dollars (millions)           H21
#
#                    Variable_name      Variable_category   Value  \
# 37079      Liabilities structure       Financial ratios      46
# ...
